# %%
import os
import torch
import data
import utils
from scipy.interpolate import interp1d
from scipy.interpolate import CubicSpline
import config as cfg
import numpy as np
import matplotlib.pyplot as plt
from copy import deepcopy
from xpbd_softbody_layer import XPBDStep
import pyvista as pv
import matplotlib.pyplot as plt
from xpbd_softbody import XPBDSoftbody
from cubic_spline import *

# %%
mesh, softbody = data.get_xpbd_grape()
# Out:
# torch.Size([600, 3])
# torch.Size([1200, 3])

# %%
control_point = 31

# %%
norm_vec = np.array([-1, 1, 0])
d = 0.005 *np.sqrt(2)/2
seg_plane = pv.Plane(center=(d,d,0), direction=norm_vec, i_size=0.02, j_size=0.01, i_resolution=10, j_resolution=10)

# %%
boundary_mask = mesh.points[:cfg.n_surf].copy()

# %%
boundary_mask = ((norm_vec @ boundary_mask.T) - 0.005 *np.sqrt(2)/2) < 0

# %%
ax = plt.figure().add_subplot(projection='3d')
ax.scatter(mesh.points[:600, 0], mesh.points[:600, 1], mesh.points[:600, 2], c=boundary_mask, marker='o')
ax.scatter(seg_plane.points[:, 0], seg_plane.points[:, 1], seg_plane.points[:, 2], c='r')
utils.axisEqual3D(ax)
ax.view_init(elev=90, azim=0)
plt.show()

# %%
def get_energy_boundary(softbody: XPBDSoftbody,
                         V_predict: torch.Tensor,
                         V_boundary_stiffness: torch.Tensor,
                         mask: set = None) -> torch.Tensor:
    
    V_boundary_stiffness_threshold = V_boundary_stiffness.clone()
    # V_boundary_stiffness_threshold[V_boundary_stiffness_threshold < 1e-3] = 0
    V_boundary_stiffness_threshold = V_boundary_stiffness_threshold * torch.sigmoid(V_boundary_stiffness_threshold - 1e-3)


    dist_C, dist_C_stiffness = __get_spring_boundary_constraints(softbody,
                                                      V_predict,
                                                      V_boundary_stiffness_threshold,
                                                      mask)
    # energy is C^2 * stiffness / 2
    boundary_energy = torch.square(dist_C) * dist_C_stiffness / 2
    return boundary_energy

def __get_spring_boundary_constraints(softbody, V_predict, V_boundary_stiffness, mask=None):
    C = []
    C_stiffness = []
    # collect all distance constraints
    for C_dist, C_init_d in zip(softbody.C_boundary_list, softbody.C_init_boundary_d_list):
        if mask == None or (C_dist[:, 0] in mask and C_dist[:, 1] in mask):
            # position difference vectors
            N = V_predict[C_dist[:, 0]] - V_predict[C_dist[:, 1]]
            # distance
            D = torch.norm(N, p=2, dim=1, keepdim=True)
            # constarint values
            C.append(D - C_init_d)
            # average stiffness
            C_stiffness.append(V_boundary_stiffness[C_dist[:, 0]])
    return torch.cat(C), torch.cat(C_stiffness)

# %%
target_boundary_stiffness = boundary_mask * 0.1
target_boundary_stiffness = torch.from_numpy(target_boundary_stiffness).to(cfg.device)

# %%
target_list = target_boundary_stiffness < 1e-2

# %%
softbody.fix_point(0, control_point)
V_origin = softbody.V.clone()
Velocity_origin = softbody.V_velocity.clone()
mesh_origin = mesh.copy()

# %%
# Hardcoded control trajectory
cloth_dist_stiffness = 1
V_boundary_stiffness = 0.1
V_dist_stiffness = torch.ones_like(softbody.V_mass).to(cfg.device)
V_boundary_stiffness = torch.ones_like(softbody.V_mass).to(cfg.device) * V_boundary_stiffness

# %%
def loss_fn(target, predict):
    return torch.norm(target - predict)

# %%
u = torch.linspace(0, 1, 3).to(cfg.device)
us = torch.linspace(0, 1, 50).to(cfg.device)
start_point = np.array([[0.000224, 0.010794, -0.001233]])
start_point = torch.from_numpy(start_point).to(cfg.device)
# spline_control = np.array([ [0.000224, 0.010794, 0.003],
#                             [0.000224, 0.010794, 0.006],
#                             [0.000224, 0.010794, 0.009]])
spline_control = np.array([ [0.000224, 0.008794, 0.0025],
                            [0.000224, 0.007794, 0.0045]])
spline_control = torch.from_numpy(spline_control).to(cfg.device)
spline_control.requires_grad_(True)
# Out:
# tensor([[0.0002, 0.0088, 0.0025],
#         [0.0002, 0.0078, 0.0045]], device='cuda:0', dtype=torch.float64,
#        requires_grad=True)

# %%
optimizer = torch.optim.Adam([spline_control], lr=0.001)

# %%
pv.set_plot_theme('document')
pl = pv.Plotter()

# skin being peeled
pl.add_mesh(mesh, color='#9f5547ff', show_edges=True, edge_color='#b37164ff',  lighting=False,style='surface')
# ellipsoid grape
grape = pv.read('assets/grape.ply')
grape.points = grape.points - np.array([0, 0, 1e-4])
pl.add_mesh(grape, color='#9f5547ff', show_edges=False, lighting=False,style='surface')

# grape meat that is green
grape_meat= pv.read('assets/grape_skin.ply')
grape_meat.points = grape_meat.points - np.array([0, 0, 2e-4])
pl.add_mesh(grape_meat, color='#c0ab5eff', show_edges=False, lighting=False,style='surface')
# Out:
# Actor (0x7f0ae555e2c0)
#   Center:                     (-9.851530194282532e-06, 0.0014494163915514946, -0.0009795548299327494)
#   Pickable:                   True
#   Position:                   (0.0, 0.0, 0.0)
#   Scale:                      (1.0, 1.0, 1.0)
#   Visible:                    True
#   X Bounds                    -6.636E-03, 6.616E-03
#   Y Bounds                    -1.040E-02, 1.330E-02
#   Z Bounds                    -3.189E-03, 1.230E-03
#   User matrix:                Set
#   Has mapper:                 True
#
# Property (0x7f0ae555e6e0)
#   Ambient:                     0.0
#   Ambient color:               Color(hex='#c0ab5eff', opacity=255)
#   Anisotropy:                  0.0
#   Color:                       Color(hex='#c0ab5eff', opacity=255)
#   Culling:                     "none"
#   Diffuse:                     1.0
#   Diffuse color:               Color(hex='#c0ab5eff', opacity=255)
#   Edge color:                  Color(name='black', hex='#000000ff', opacity=255)
#   Edge opacity:                1.0
#   Interpolation:               0
#   Lighting:                    False
#   Line width:                  1.0
#   Metallic:                    0.0
#   Opacity:                     1.0
#   Point size:                  5.0
#   Render lines as tubes:       False
#   Render points as spheres:    False
#   Roughness:                   0.5
#   Show edges:                  False
#   Specular:                    0.0
#   Specular color:              Color(hex='#c0ab5eff', opacity=255)
#   Specular power:              100.0
#   Style:                       "Surface"
#
# DataSetMapper (0x7f0ae555dfc0)
#   Scalar visibility:           False
#   Scalar range:                (0.0, 1.0)
#   Interpolate before mapping:  True
#   Scalar map mode:             default
#   Color mode:                  direct
#
# Attached dataset:
# PolyData (0x7f0ae555e200)
#   N Cells:    588
#   N Points:   380
#   N Strips:   0
#   X Bounds:   -6.636e-03, 6.616e-03
#   Y Bounds:   -1.040e-02, 1.330e-02
#   Z Bounds:   -3.189e-03, 1.230e-03
#   N Arrays:   0

# %%
control = []
loss_list = []
spline_list = []
pre_loss = 100

# %%
for t in range(30):
    print(t)
    x_con = torch.cat((start_point[:, 0], spline_control[:, 0]))
    y_con = torch.cat((start_point[:, 1], spline_control[:, 1]))
    z_con = torch.cat((start_point[:, 2], spline_control[:, 2]))
    spline_x = interp(u, x_con, us)
    spline_y = interp(u, y_con, us)
    spline_z = interp(u, z_con, us)

    spline_trajectory = torch.transpose(torch.vstack((spline_x, spline_y, spline_z)), 0, 1)
    spline_list.append(spline_trajectory.detach().cpu().numpy())
    # reset for each test
    softbody.V = V_origin.clone()
    softbody.V_velocity = Velocity_origin.clone()

    cloth_dist_stiffness = 1
    V_boundary_stiffness = 0.1
    V_dist_stiffness = torch.ones_like(softbody.V_mass).to(cfg.device)
    V_boundary_stiffness = torch.ones_like(softbody.V_mass).to(cfg.device) * V_boundary_stiffness
    
    for i in range(spline_trajectory.shape[0]):
        softbody.V[control_point] = spline_trajectory[i]
        step_ref = XPBDStep(softbody,
                        V_dist_stiffness=V_dist_stiffness, 
                        V_shape_stiffness=None,
                        V_boundary_stiffness=V_boundary_stiffness, 
                        dt=cfg.dt,
                        substep=cfg.substep,
                        iteration=cfg.iteration,
                        quasi_static=cfg.quasi_static,
                        plane_height=cfg.ground_plane_height, 
                        use_shape_matching=cfg.use_shape_matching,
                        use_spring_boundary=cfg.use_spring_boundary) #cfg.use_spring_boundary
        V_ref, V_velocity_ref = step_ref.forward(softbody.V, softbody.V_velocity)
        softbody.V = V_ref.clone()
        softbody.V_velocity = V_velocity_ref.clone()
        ref_V_boundary_stiffness = V_boundary_stiffness[:cfg.n_surf].detach().clone()
        energy = get_energy_boundary(softbody, softbody.V, ref_V_boundary_stiffness)
        V_boundary_stiffness[:cfg.n_surf] = ref_V_boundary_stiffness * torch.sigmoid(1e9 * (1e-8 - energy))

    # interpolate trajectory
    break_list = V_boundary_stiffness[:cfg.n_surf].detach() < 1e-2
    score = torch.sum(break_list.reshape(cfg.n_surf) & target_list) / torch.sum(target_list)
    loss = loss_fn(target_boundary_stiffness, V_boundary_stiffness[:cfg.n_surf].reshape(cfg.n_surf))
    loss.backward()
    
    loss_list.append(loss.detach().cpu())
    print(loss)
    print(spline_control.grad)
    print(score)
    # if score > 0.9:
    #     break
    optimizer.step()
    optimizer.zero_grad()
    
    mesh.points = softbody.V.detach().cpu().numpy()
    # pl.show(interactive_update=True)
# Out:
# 0
# tensor(0.6324, device='cuda:0', dtype=torch.float64,
#        grad_fn=<LinalgVectorNormBackward0>)
# tensor([[-0.0005,  0.0002, -0.0002],
#         [-0.0102, -0.0052, -0.0026]], device='cuda:0', dtype=torch.float64)
# tensor(0.9737, device='cuda:0')
# 1
# tensor(0.6382, device='cuda:0', dtype=torch.float64,
#        grad_fn=<LinalgVectorNormBackward0>)
# tensor([[-7.7828e-04,  7.7783e-05, -1.8940e-04],
#         [-1.1780e-02, -6.0163e-03, -2.4499e-03]], device='cuda:0',
#        dtype=torch.float64)
# tensor(0.9737, device='cuda:0')
# 2
# tensor(0.6524, device='cuda:0', dtype=torch.float64,
#        grad_fn=<LinalgVectorNormBackward0>)
# tensor([[-0.0004,  0.0007, -0.0004],
#         [-0.0089, -0.0036, -0.0037]], device='cuda:0', dtype=torch.float64)
# tensor(0.9789, device='cuda:0')
# 3
# tensor(0.6561, device='cuda:0', dtype=torch.float64,
#        grad_fn=<LinalgVectorNormBackward0>)
# tensor([[ 4.7080e-06,  2.6105e-04, -4.2004e-04],
#         [-1.2094e-03, -2.9265e-04, -2.3089e-03]], device='cuda:0',
#        dtype=torch.float64)
# tensor(0.9789, device='cuda:0')
# 4
# tensor(0.6610, device='cuda:0', dtype=torch.float64,
#        grad_fn=<LinalgVectorNormBackward0>)
# tensor([[-3.7058e-05,  2.5808e-04, -3.8078e-04],
#         [-1.6040e-03, -4.5337e-04, -2.0219e-03]], device='cuda:0',
#        dtype=torch.float64)
# tensor(0.9789, device='cuda:0')
# 5
# tensor(0.6671, device='cuda:0', dtype=torch.float64,
#        grad_fn=<LinalgVectorNormBackward0>)
# tensor([[ 3.6366e-05,  2.8860e-04, -4.2217e-04],
#         [-5.3113e-04,  5.4880e-05, -1.9286e-03]], device='cuda:0',
#        dtype=torch.float64)
# tensor(0.9789, device='cuda:0')
# 6
# tensor(0.6584, device='cuda:0', dtype=torch.float64,
#        grad_fn=<LinalgVectorNormBackward0>)
# tensor([[-0.0002,  0.0002, -0.0005],
#         [-0.0045, -0.0021, -0.0026]], device='cuda:0', dtype=torch.float64)
# tensor(0.9789, device='cuda:0')
# 7
# tensor(0.6677, device='cuda:0', dtype=torch.float64,
#        grad_fn=<LinalgVectorNormBackward0>)
# tensor([[-2.7638e-05,  5.4856e-05, -5.5802e-04],
#         [-4.1551e-03, -1.9664e-03, -2.4041e-03]], device='cuda:0',
#        dtype=torch.float64)
# tensor(0.9789, device='cuda:0')
# 8
# tensor(0.6702, device='cuda:0', dtype=torch.float64,
#        grad_fn=<LinalgVectorNormBackward0>)
# tensor([[-1.1556e-05,  1.5492e-04, -3.0525e-04],
#         [-1.8770e-03, -8.4743e-04, -1.5243e-03]], device='cuda:0',
#        dtype=torch.float64)
# tensor(0.9789, device='cuda:0')
# 9
# tensor(0.6756, device='cuda:0', dtype=torch.float64,
#        grad_fn=<LinalgVectorNormBackward0>)
# tensor([[-5.2531e-05,  1.9411e-04, -2.9454e-04],
#         [-1.7727e-03, -7.5440e-04, -1.4639e-03]], device='cuda:0',
#        dtype=torch.float64)
# tensor(0.9789, device='cuda:0')
# 10
# tensor(0.6767, device='cuda:0', dtype=torch.float64,
#        grad_fn=<LinalgVectorNormBackward0>)
# tensor([[ 9.2623e-05,  3.3228e-04, -4.5829e-04],
#         [-1.4361e-03, -4.9347e-04, -2.2275e-03]], device='cuda:0',
#        dtype=torch.float64)
# tensor(0.9789, device='cuda:0')
# 11
# tensor(0.6779, device='cuda:0', dtype=torch.float64,
#        grad_fn=<LinalgVectorNormBackward0>)
# tensor([[ 1.3511e-04,  4.0110e-04, -4.4037e-04],
#         [-9.5382e-04, -5.2096e-05, -2.0624e-03]], device='cuda:0',
#        dtype=torch.float64)
# tensor(0.9789, device='cuda:0')
# 12
# tensor(0.6857, device='cuda:0', dtype=torch.float64,
#        grad_fn=<LinalgVectorNormBackward0>)
# tensor([[-6.2234e-05,  2.8490e-04, -2.6030e-04],
#         [-2.5997e-03, -8.9978e-04, -1.5301e-03]], device='cuda:0',
#        dtype=torch.float64)
# tensor(0.9789, device='cuda:0')
# 13
# tensor(0.6842, device='cuda:0', dtype=torch.float64,
#        grad_fn=<LinalgVectorNormBackward0>)
# tensor([[-0.0001,  0.0002, -0.0003],
#         [-0.0022, -0.0007, -0.0017]], device='cuda:0', dtype=torch.float64)
# tensor(0.9789, device='cuda:0')
# 14
# tensor(0.6807, device='cuda:0', dtype=torch.float64,
#        grad_fn=<LinalgVectorNormBackward0>)
# tensor([[-7.4107e-06,  1.8747e-04, -2.8339e-04],
#         [-1.8125e-03, -6.6802e-04, -1.5698e-03]], device='cuda:0',
#        dtype=torch.float64)
# tensor(0.9789, device='cuda:0')
# 15
# tensor(0.6744, device='cuda:0', dtype=torch.float64,
#        grad_fn=<LinalgVectorNormBackward0>)
# tensor([[-4.4180e-05,  7.3534e-05, -2.0648e-04],
#         [-1.1472e-03, -4.0143e-04, -1.1681e-03]], device='cuda:0',
#        dtype=torch.float64)
# tensor(0.9789, device='cuda:0')
# 16
# tensor(0.6800, device='cuda:0', dtype=torch.float64,
#        grad_fn=<LinalgVectorNormBackward0>)
# tensor([[-0.0002,  0.0002, -0.0003],
#         [-0.0029, -0.0011, -0.0018]], device='cuda:0', dtype=torch.float64)
# tensor(0.9789, device='cuda:0')
# 17
# tensor(0.6770, device='cuda:0', dtype=torch.float64,
#        grad_fn=<LinalgVectorNormBackward0>)
# tensor([[ 2.1467e-04, -2.3261e-05, -1.5791e-04],
#         [-1.5194e-03, -1.0215e-03, -1.3106e-03]], device='cuda:0',
#        dtype=torch.float64)
# tensor(0.9789, device='cuda:0')
# 18
# tensor(0.6773, device='cuda:0', dtype=torch.float64,
#        grad_fn=<LinalgVectorNormBackward0>)
# tensor([[-3.2147e-04, -8.4909e-07, -2.5265e-04],
#         [-2.9008e-03, -9.7088e-04, -1.5472e-03]], device='cuda:0',
#        dtype=torch.float64)
# tensor(0.9789, device='cuda:0')
# 19
# tensor(0.6790, device='cuda:0', dtype=torch.float64,
#        grad_fn=<LinalgVectorNormBackward0>)
# tensor([[-0.0002,  0.0001, -0.0002],
#         [-0.0021, -0.0008, -0.0012]], device='cuda:0', dtype=torch.float64)
# tensor(0.9789, device='cuda:0')
# 20
# tensor(0.6881, device='cuda:0', dtype=torch.float64,
#        grad_fn=<LinalgVectorNormBackward0>)
# tensor([[-0.0002,  0.0001, -0.0002],
#         [-0.0021, -0.0007, -0.0012]], device='cuda:0', dtype=torch.float64)
# tensor(0.9789, device='cuda:0')
# 21
# tensor(0.6899, device='cuda:0', dtype=torch.float64,
#        grad_fn=<LinalgVectorNormBackward0>)
# tensor([[-1.9311e-04,  7.2052e-05, -2.2182e-04],
#         [-2.4759e-03, -9.3391e-04, -1.2197e-03]], device='cuda:0',
#        dtype=torch.float64)
# tensor(0.9789, device='cuda:0')
# 22
# tensor(0.6995, device='cuda:0', dtype=torch.float64,
#        grad_fn=<LinalgVectorNormBackward0>)
# tensor([[-1.8100e-04,  8.5256e-05, -1.7936e-04],
#         [-2.3606e-03, -9.0115e-04, -1.1852e-03]], device='cuda:0',
#        dtype=torch.float64)
# tensor(0.9789, device='cuda:0')
# 23

# %%
ax = plt.figure().add_subplot(projection='3d')
ax.scatter(mesh.points[:600, 0], mesh.points[:600, 1], mesh.points[:600, 2], c='g', marker='o', label='grape')
ax.scatter(spline_trajectory[:, 0].cpu().detach(), spline_trajectory[:, 1].cpu().detach(), spline_trajectory[:, 2].cpu().detach(), c='r', marker='o', label='optimal trajectory')
ax.scatter(spline_control[:, 0].cpu().detach(), spline_control[:, 1].cpu().detach(), spline_control[:, 2].cpu().detach(), c='b', marker='o', label='control point')
ax.scatter(start_point[:, 0].cpu().detach(), start_point[:, 1].cpu().detach(), start_point[:, 2].cpu().detach(), c='y', marker='o', label='start point')
ax.scatter(spline_list[0][:, 0], spline_list[0][:, 1], spline_list[0][:, 2])
utils.axisEqual3D(ax)
ax.view_init(elev=0, azim=0)
ax.legend()
plt.show()

# %%
spline_mesh = mesh.copy()

# %%
ax = plt.figure().add_subplot(projection='3d')
for i in spline_list[-2:-1]:
    ax.scatter(i[:, 0], i[:, 1], i[:, 2], marker='o')

# %%
plt.plot(loss_list)
plt.title('loss vs iteration')
plt.xlabel('times')
plt.ylabel('loss')
# Out:
# Text(0, 0.5, 'loss')

# %%
spline_control
# Out:
# tensor([[ 0.0134, -0.0030,  0.0030],
#         [ 0.0090,  0.0054,  0.0018]], device='cuda:0', dtype=torch.float64,
#        requires_grad=True)

# %%
spline_line = spline_trajectory.detach().cpu().numpy()

# %%
pv.set_plot_theme('document')
pl = pv.Plotter()

# skin being peeled
pl.add_mesh(spline_mesh, color='#9f5547ff', show_edges=True, edge_color='#b37164ff',  lighting=False,style='surface')
pl.add_mesh(mesh_origin, scalars=target_list.cpu(), show_edges=True, edge_color='#b37164ff',  lighting=False,style='surface')

# control line
pl.add_lines(spline_line, color='r', connected=True)
# ellipsoid grape
grape = pv.read('assets/grape.ply')
grape.points = grape.points - np.array([0, 0, 1e-4])
pl.add_mesh(grape, color='#9f5547ff', show_edges=False, lighting=False,style='surface')

# grape meat that is green
grape_meat= pv.read('assets/grape_skin.ply')
grape_meat.points = grape_meat.points - np.array([0, 0, 2e-4])
pl.add_mesh(grape_meat, color='#c0ab5eff', show_edges=False, lighting=False,style='surface')
pl.show()
# Out:
# /home/youcheng/anaconda3/envs/py_pbd/lib/python3.10/site-packages/pyvista/jupyter/notebook.py:34: UserWarning: Failed to use notebook backend:
#
# cannot import name 'vtk' from 'trame.widgets' (/home/youcheng/anaconda3/envs/py_pbd/lib/python3.10/site-packages/trame/widgets/__init__.py)
#
# Falling back to a static output.
#   warnings.warn(
# <PIL.Image.Image image mode=RGB size=1024x768>

# %%
mesh, softbody = data.get_xpbd_grape()
softbody.fix_point(0, control_point)
mesh_origin = mesh.copy()
# Out:
# torch.Size([600, 3])
# torch.Size([1200, 3])

# %%
pv.set_plot_theme('document')
pl = pv.Plotter()
# skin being peeled
pl.add_mesh(mesh_origin, scalars=target_list.cpu(), show_edges=True, edge_color='#b37164ff',  lighting=False,style='surface')
pl.add_mesh(mesh, color='#9f5547ff', show_edges=True, edge_color='#b37164ff',  lighting=False,style='surface')

# control line
# pl.add_lines(spline_line, color='r', connected=True)
# ellipsoid grape
grape = pv.read('assets/grape.ply')
grape.points = grape.points - np.array([0, 0, 1e-4])
pl.add_mesh(grape, color='#9f5547ff', show_edges=False, lighting=False,style='surface')

# grape meat that is green
grape_meat= pv.read('assets/grape_skin.ply')
grape_meat.points = grape_meat.points - np.array([0, 0, 2e-4])
pl.add_mesh(grape_meat, color='#c0ab5eff', show_edges=False, lighting=False,style='surface')
# Out:
# Actor (0x7f0ae4e83820)
#   Center:                     (-9.851530194282532e-06, 0.0014494163915514946, -0.0009795548299327494)
#   Pickable:                   True
#   Position:                   (0.0, 0.0, 0.0)
#   Scale:                      (1.0, 1.0, 1.0)
#   Visible:                    True
#   X Bounds                    -6.636E-03, 6.616E-03
#   Y Bounds                    -1.040E-02, 1.330E-02
#   Z Bounds                    -3.189E-03, 1.230E-03
#   User matrix:                Set
#   Has mapper:                 True
#
# Property (0x7f0ae4e83e80)
#   Ambient:                     0.0
#   Ambient color:               Color(hex='#c0ab5eff', opacity=255)
#   Anisotropy:                  0.0
#   Color:                       Color(hex='#c0ab5eff', opacity=255)
#   Culling:                     "none"
#   Diffuse:                     1.0
#   Diffuse color:               Color(hex='#c0ab5eff', opacity=255)
#   Edge color:                  Color(name='black', hex='#000000ff', opacity=255)
#   Edge opacity:                1.0
#   Interpolation:               0
#   Lighting:                    False
#   Line width:                  1.0
#   Metallic:                    0.0
#   Opacity:                     1.0
#   Point size:                  5.0
#   Render lines as tubes:       False
#   Render points as spheres:    False
#   Roughness:                   0.5
#   Show edges:                  False
#   Specular:                    0.0
#   Specular color:              Color(hex='#c0ab5eff', opacity=255)
#   Specular power:              100.0
#   Style:                       "Surface"
#
# DataSetMapper (0x7f0ae4e82a40)
#   Scalar visibility:           False
#   Scalar range:                (0.0, 1.0)
#   Interpolate before mapping:  True
#   Scalar map mode:             default
#   Color mode:                  direct
#
# Attached dataset:
# PolyData (0x7f0ae4e83a00)
#   N Cells:    588
#   N Points:   380
#   N Strips:   0
#   X Bounds:   -6.636e-03, 6.616e-03
#   Y Bounds:   -1.040e-02, 1.330e-02
#   Z Bounds:   -3.189e-03, 1.230e-03
#   N Arrays:   0

# %%
# pl.show()

# %%
x_con = torch.cat((start_point[:, 0], spline_control[:, 0]))
y_con = torch.cat((start_point[:, 1], spline_control[:, 1]))
z_con = torch.cat((start_point[:, 2], spline_control[:, 2]))
spline_x = interp(u, x_con, us)
spline_y = interp(u, y_con, us)
spline_z = interp(u, z_con, us)

spline_trajectory = torch.transpose(torch.vstack((spline_x, spline_y, spline_z)), 0, 1)
spline_list.append(spline_trajectory.detach().cpu().numpy())
# reset for each test
softbody.V = V_origin.clone()
softbody.V_velocity = Velocity_origin.clone()

cloth_dist_stiffness = 1
V_boundary_stiffness = 0.1
V_dist_stiffness = torch.ones_like(softbody.V_mass).to(cfg.device)
V_boundary_stiffness = torch.ones_like(softbody.V_mass).to(cfg.device) * V_boundary_stiffness
pl.open_gif('boundary_based_optimize_tilted2.gif')
for i in range(spline_trajectory.shape[0]):
    softbody.V[control_point] = spline_trajectory[i]
    step_ref = XPBDStep(softbody,
                    V_dist_stiffness=V_dist_stiffness, 
                    V_shape_stiffness=None,
                    V_boundary_stiffness=V_boundary_stiffness, 
                    dt=cfg.dt,
                    substep=cfg.substep,
                    iteration=cfg.iteration,
                    quasi_static=cfg.quasi_static,
                    plane_height=cfg.ground_plane_height, 
                    use_shape_matching=cfg.use_shape_matching,
                    use_spring_boundary=cfg.use_spring_boundary) #cfg.use_spring_boundary
    V_ref, V_velocity_ref = step_ref.forward(softbody.V, softbody.V_velocity)
    softbody.V = V_ref.clone()
    softbody.V_velocity = V_velocity_ref.clone()
    ref_V_boundary_stiffness = V_boundary_stiffness[:cfg.n_surf].detach().clone()
    energy = get_energy_boundary(softbody, softbody.V, ref_V_boundary_stiffness)
    V_boundary_stiffness[:cfg.n_surf] = ref_V_boundary_stiffness * torch.sigmoid(1e9 * (1e-8 - energy))
    mesh.points = softbody.V.detach().cpu().numpy()
    # pl.update()
    pl.write_frame()
pl.close()
