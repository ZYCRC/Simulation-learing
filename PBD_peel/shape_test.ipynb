# %%
from xpbd_softbody import XPBDSoftbody
import pyvista as pv
import config as cfg
import matplotlib.pyplot as plt
import torch
from xpbd_softbody_layer import XPBDStep

# %%
#load a shape
softbody = XPBDSoftbody()
mesh = softbody.add_thinshell(pv.Plane(), n_surf=10)
softbody.init_states()
# softbody.set_gravity(torch.tensor([0, 0, -9.8]).to(cfg.device))
# softbody.init_dist_constraints()
# softbody.fix_point(0, 1)
softbody.init_shape_constraints_thinshell()

# %%
softbody.C_init_shape_list
# Out:
# [tensor([[[-0.2026, -0.1777,  0.0000],
#           [ 0.1312, -0.1778,  0.0000],
#           [-0.0022,  0.1587,  0.0000]],
#
#          [[ 0.1633,  0.0698,  0.0000],
#           [-0.0874,  0.0711,  0.0000],
#           [ 0.1137, -0.2666,  0.0000]]], device='cuda:0'),
#  tensor([[[-0.1130, -0.2658,  0.0000],
#           [ 0.0873,  0.0706,  0.0000],
#           [-0.1638,  0.0708,  0.0000]],
#
#          [[-0.1294, -0.1786,  0.0000],
#           [ 0.2025, -0.1782,  0.0000],
#           [ 0.0014,  0.1594,  0.0000]]], device='cuda:0'),
#  tensor([[[ 0.1319,  0.0734,  0.0000],
#           [-0.1323,  0.0718,  0.0000],
#           [ 0.0011, -0.2647,  0.0000]]], device='cuda:0'),
#  tensor([[[-0.1319, -0.0733,  0.0000],
#           [ 0.1322, -0.0717,  0.0000],
#           [-0.0003,  0.2644,  0.0000]]], device='cuda:0'),
#  tensor([[[-0.1136,  0.2663,  0.0000],
#           [-0.1636, -0.0706,  0.0000],
#           [ 0.0875, -0.0708,  0.0000]],
#
#          [[-0.0873, -0.0702,  0.0000],
#           [ 0.1634, -0.0715,  0.0000],
#           [ 0.1132,  0.2656,  0.0000]]], device='cuda:0'),
#  tensor([[[ 0.1301,  0.1786,  0.0000],
#           [-0.2026,  0.1780,  0.0000],
#           [-0.0015, -0.1591,  0.0000]]], device='cuda:0'),
#  tensor([[[ 0.2025,  0.1773,  0.0000],
#           [-0.1306,  0.1777,  0.0000],
#           [ 0.0020, -0.1584,  0.0000]]], device='cuda:0')]

# %%
statics = torch.zeros(10)
for entry in softbody.C_shape_list:
    for item in entry:
        statics[item] += 1

# %%
pl = pv.Plotter()
pl.add_mesh(mesh, scalars=statics, show_edges=True, edge_color='#b37164ff',  lighting=False,style='surface', cmap='jet')
pl.show()
# Out:
# /home/youcheng/anaconda3/envs/py_pbd/lib/python3.10/site-packages/pyvista/jupyter/notebook.py:34: UserWarning: Failed to use notebook backend:
#
# cannot import name 'vtk' from 'trame.widgets' (/home/youcheng/anaconda3/envs/py_pbd/lib/python3.10/site-packages/trame/widgets/__init__.py)
#
# Falling back to a static output.
#   warnings.warn(
# <PIL.Image.Image image mode=RGB size=1024x768>

# %%
V_shape_stiffness = torch.ones_like(softbody.V_mass).to(cfg.device)
V_dist_stiffness = torch.ones_like(softbody.V_mass).to(cfg.device)

# %%
mesh.points[1]
# Out:
# pyvista_ndarray([ 0.00166212, -0.33699854,  0.        ])

# %%
for i in range(10):
    print(i)
    # softbody.V[1][-1] += 0.001
    step_ref = XPBDStep(softbody,
                V_dist_stiffness=V_dist_stiffness, 
                V_shape_stiffness=V_shape_stiffness,
                V_boundary_stiffness=None, 
                dt=cfg.dt,
                substep=cfg.substep,
                iteration=cfg.iteration,
                quasi_static=cfg.quasi_static,
                plane_height=cfg.ground_plane_height, 
                use_shape_matching=True,
                use_spring_boundary=False) #cfg.use_spring_boundary
    V_ref, V_velocity_ref = step_ref.forward(softbody.V, softbody.V_velocity)
    softbody.V = V_ref.clone()
    softbody.V_velocity = V_velocity_ref.clone()
    mesh.points = softbody.V.cpu().numpy()
    pl.show(interactive_update=True)
# Out:
# 0
# /home/youcheng/anaconda3/envs/py_pbd/lib/python3.10/site-packages/pyvista/jupyter/notebook.py:34: UserWarning: Failed to use notebook backend:
#
# cannot import name 'vtk' from 'trame.widgets' (/home/youcheng/anaconda3/envs/py_pbd/lib/python3.10/site-packages/trame/widgets/__init__.py)
#
# Falling back to a static output.
#   warnings.warn(
# <PIL.Image.Image image mode=RGB size=1024x768>
# 1
# /home/youcheng/anaconda3/envs/py_pbd/lib/python3.10/site-packages/pyvista/jupyter/notebook.py:34: UserWarning: Failed to use notebook backend:
#
# cannot import name 'vtk' from 'trame.widgets' (/home/youcheng/anaconda3/envs/py_pbd/lib/python3.10/site-packages/trame/widgets/__init__.py)
#
# Falling back to a static output.
#   warnings.warn(
# <PIL.Image.Image image mode=RGB size=1024x768>
# 2
# /home/youcheng/anaconda3/envs/py_pbd/lib/python3.10/site-packages/pyvista/jupyter/notebook.py:34: UserWarning: Failed to use notebook backend:
#
# cannot import name 'vtk' from 'trame.widgets' (/home/youcheng/anaconda3/envs/py_pbd/lib/python3.10/site-packages/trame/widgets/__init__.py)
#
# Falling back to a static output.
#   warnings.warn(
# <PIL.Image.Image image mode=RGB size=1024x768>
# 3
# /home/youcheng/anaconda3/envs/py_pbd/lib/python3.10/site-packages/pyvista/jupyter/notebook.py:34: UserWarning: Failed to use notebook backend:
#
# cannot import name 'vtk' from 'trame.widgets' (/home/youcheng/anaconda3/envs/py_pbd/lib/python3.10/site-packages/trame/widgets/__init__.py)
#
# Falling back to a static output.
#   warnings.warn(
# <PIL.Image.Image image mode=RGB size=1024x768>
# 4
# /home/youcheng/anaconda3/envs/py_pbd/lib/python3.10/site-packages/pyvista/jupyter/notebook.py:34: UserWarning: Failed to use notebook backend:
#
# cannot import name 'vtk' from 'trame.widgets' (/home/youcheng/anaconda3/envs/py_pbd/lib/python3.10/site-packages/trame/widgets/__init__.py)
#
# Falling back to a static output.
#   warnings.warn(
# <PIL.Image.Image image mode=RGB size=1024x768>
# 5
# /home/youcheng/anaconda3/envs/py_pbd/lib/python3.10/site-packages/pyvista/jupyter/notebook.py:34: UserWarning: Failed to use notebook backend:
#
# cannot import name 'vtk' from 'trame.widgets' (/home/youcheng/anaconda3/envs/py_pbd/lib/python3.10/site-packages/trame/widgets/__init__.py)
#
# Falling back to a static output.
#   warnings.warn(
# <PIL.Image.Image image mode=RGB size=1024x768>
# 6
# /home/youcheng/anaconda3/envs/py_pbd/lib/python3.10/site-packages/pyvista/jupyter/notebook.py:34: UserWarning: Failed to use notebook backend:
#
# cannot import name 'vtk' from 'trame.widgets' (/home/youcheng/anaconda3/envs/py_pbd/lib/python3.10/site-packages/trame/widgets/__init__.py)
#
# Falling back to a static output.
#   warnings.warn(
# <PIL.Image.Image image mode=RGB size=1024x768>
# 7
# /home/youcheng/anaconda3/envs/py_pbd/lib/python3.10/site-packages/pyvista/jupyter/notebook.py:34: UserWarning: Failed to use notebook backend:
#
# cannot import name 'vtk' from 'trame.widgets' (/home/youcheng/anaconda3/envs/py_pbd/lib/python3.10/site-packages/trame/widgets/__init__.py)
#
# Falling back to a static output.
#   warnings.warn(
# <PIL.Image.Image image mode=RGB size=1024x768>
# 8
# /home/youcheng/anaconda3/envs/py_pbd/lib/python3.10/site-packages/pyvista/jupyter/notebook.py:34: UserWarning: Failed to use notebook backend:
#
# cannot import name 'vtk' from 'trame.widgets' (/home/youcheng/anaconda3/envs/py_pbd/lib/python3.10/site-packages/trame/widgets/__init__.py)
#
# Falling back to a static output.
#   warnings.warn(
# <PIL.Image.Image image mode=RGB size=1024x768>
# 9
# /home/youcheng/anaconda3/envs/py_pbd/lib/python3.10/site-packages/pyvista/jupyter/notebook.py:34: UserWarning: Failed to use notebook backend:
#
# cannot import name 'vtk' from 'trame.widgets' (/home/youcheng/anaconda3/envs/py_pbd/lib/python3.10/site-packages/trame/widgets/__init__.py)
#
# Falling back to a static output.
#   warnings.warn(
# <PIL.Image.Image image mode=RGB size=1024x768>
